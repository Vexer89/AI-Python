# %%
from stable_baselines3 import PPO
import  gymnasium as gym
from collections import defaultdict
import numpy as np

# %%
env = gym.make("CartPole-v1")

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=100_000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | 21.7     |
# | time/              |          |
# |    fps             | 6472     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 24.6        |
# | time/                   |             |
# |    fps                  | 4136        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009581953 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.00178    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.79        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 52.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.8        |
# |    ep_rew_mean          | 31.8        |
# | time/                   |             |
# |    fps                  | 3878        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011171766 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 30.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.6         |
# |    ep_rew_mean          | 43.6         |
# | time/                   |              |
# |    fps                  | 3739         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0098698195 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | 0.241        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.1         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.019       |
# |    value_loss           | 47.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59          |
# |    ep_rew_mean          | 59          |
# | time/                   |             |
# |    fps                  | 3646        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009113388 |
# |    clip_fraction        | 0.0739      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 59.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 75.7       |
# |    ep_rew_mean          | 75.7       |
# | time/                   |            |
# |    fps                  | 3606       |
# |    iterations           | 6          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01046354 |
# |    clip_fraction        | 0.071      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.599     |
# |    explained_variance   | 0.437      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 37.1       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0165    |
# |    value_loss           | 55.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.9        |
# |    ep_rew_mean          | 92.9        |
# | time/                   |             |
# |    fps                  | 3529        |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.003113687 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00881    |
# |    value_loss           | 58          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 112          |
# |    ep_rew_mean          | 112          |
# | time/                   |              |
# |    fps                  | 3497         |
# |    iterations           | 8            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0037261003 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.666        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.8         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00844     |
# |    value_loss           | 49.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 126         |
# | time/                   |             |
# |    fps                  | 3471        |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009970517 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.37        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 53.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 147          |
# |    ep_rew_mean          | 147          |
# | time/                   |              |
# |    fps                  | 3457         |
# |    iterations           | 10           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0058272085 |
# |    clip_fraction        | 0.061        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.568       |
# |    explained_variance   | 0.654        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.4         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00678     |
# |    value_loss           | 49.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 3444         |
# |    iterations           | 11           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0063646585 |
# |    clip_fraction        | 0.0832       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.562       |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.56         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0138      |
# |    value_loss           | 19           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | 184         |
# | time/                   |             |
# |    fps                  | 3429        |
# |    iterations           | 12          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007913595 |
# |    clip_fraction        | 0.0567      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.541      |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.96        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 23.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | 202         |
# | time/                   |             |
# |    fps                  | 3415        |
# |    iterations           | 13          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.016159303 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.68        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00373    |
# |    value_loss           | 14.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 220         |
# |    ep_rew_mean          | 220         |
# | time/                   |             |
# |    fps                  | 3414        |
# |    iterations           | 14          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006040392 |
# |    clip_fraction        | 0.0208      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 5.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 237         |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 3414        |
# |    iterations           | 15          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009272726 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.521      |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.305       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00481    |
# |    value_loss           | 2.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 256         |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 3412        |
# |    iterations           | 16          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009937972 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.505      |
# |    explained_variance   | 0.673       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.201       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00649    |
# |    value_loss           | 1.73        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 273        |
# |    ep_rew_mean          | 273        |
# | time/                   |            |
# |    fps                  | 3410       |
# |    iterations           | 17         |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00906313 |
# |    clip_fraction        | 0.055      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.486     |
# |    explained_variance   | 0.818      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0455     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00323   |
# |    value_loss           | 0.714      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 291          |
# |    ep_rew_mean          | 291          |
# | time/                   |              |
# |    fps                  | 3409         |
# |    iterations           | 18           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0028990859 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | 0.348        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00936      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 0.404        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 307          |
# |    ep_rew_mean          | 307          |
# | time/                   |              |
# |    fps                  | 3408         |
# |    iterations           | 19           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0068741483 |
# |    clip_fraction        | 0.0892       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.478       |
# |    explained_variance   | 0.344        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0277       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00503     |
# |    value_loss           | 0.262        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 324          |
# |    ep_rew_mean          | 324          |
# | time/                   |              |
# |    fps                  | 3405         |
# |    iterations           | 20           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0017160994 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.455       |
# |    explained_variance   | 0.24         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0348       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.000252     |
# |    value_loss           | 0.172        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 341          |
# |    ep_rew_mean          | 341          |
# | time/                   |              |
# |    fps                  | 3401         |
# |    iterations           | 21           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0046761297 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.435       |
# |    explained_variance   | 0.0302       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0133      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 0.109        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 362         |
# |    ep_rew_mean          | 362         |
# | time/                   |             |
# |    fps                  | 3400        |
# |    iterations           | 22          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005493799 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | 0.0751      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00326     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00139    |
# |    value_loss           | 0.0695      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 376           |
# |    ep_rew_mean          | 376           |
# | time/                   |               |
# |    fps                  | 3400          |
# |    iterations           | 23            |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00062050053 |
# |    clip_fraction        | 0.00391       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.429        |
# |    explained_variance   | 0.126         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00397       |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -4.08e-05     |
# |    value_loss           | 0.0428        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 389          |
# |    ep_rew_mean          | 389          |
# | time/                   |              |
# |    fps                  | 3401         |
# |    iterations           | 24           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0027854992 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.438       |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0186       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00091     |
# |    value_loss           | 0.0284       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 403          |
# |    ep_rew_mean          | 403          |
# | time/                   |              |
# |    fps                  | 3400         |
# |    iterations           | 25           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0026744283 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.445       |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00288     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.000212     |
# |    value_loss           | 0.018        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 417          |
# |    ep_rew_mean          | 417          |
# | time/                   |              |
# |    fps                  | 3397         |
# |    iterations           | 26           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0025607229 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.42        |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0049      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00039     |
# |    value_loss           | 0.0119       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 431           |
# |    ep_rew_mean          | 431           |
# | time/                   |               |
# |    fps                  | 3395          |
# |    iterations           | 27            |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00071689434 |
# |    clip_fraction        | 0.014         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.438        |
# |    explained_variance   | 0.144         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00145       |
# |    n_updates            | 260           |
# |    policy_gradient_loss | 0.000234      |
# |    value_loss           | 0.00785       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 442           |
# |    ep_rew_mean          | 442           |
# | time/                   |               |
# |    fps                  | 3374          |
# |    iterations           | 28            |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00044901913 |
# |    clip_fraction        | 0.0148        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.425        |
# |    explained_variance   | 0.213         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00485       |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.00022      |
# |    value_loss           | 0.00512       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 454          |
# |    ep_rew_mean          | 454          |
# | time/                   |              |
# |    fps                  | 3372         |
# |    iterations           | 29           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0056817206 |
# |    clip_fraction        | 0.0833       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.413       |
# |    explained_variance   | 0.368        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00466     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00611     |
# |    value_loss           | 0.00339      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 462           |
# |    ep_rew_mean          | 462           |
# | time/                   |               |
# |    fps                  | 3371          |
# |    iterations           | 30            |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00073006656 |
# |    clip_fraction        | 0.00693       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.421        |
# |    explained_variance   | 0.295         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00184       |
# |    n_updates            | 290           |
# |    policy_gradient_loss | 0.00031       |
# |    value_loss           | 0.00234       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 470         |
# |    ep_rew_mean          | 470         |
# | time/                   |             |
# |    fps                  | 3368        |
# |    iterations           | 31          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.002044166 |
# |    clip_fraction        | 0.0346      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.409      |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.017       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 0.00156     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 485          |
# |    ep_rew_mean          | 485          |
# | time/                   |              |
# |    fps                  | 3367         |
# |    iterations           | 32           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0048843157 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.379       |
# |    explained_variance   | 0.512        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00902     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00368     |
# |    value_loss           | 0.0011       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 495          |
# |    ep_rew_mean          | 495          |
# | time/                   |              |
# |    fps                  | 3368         |
# |    iterations           | 33           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0068251984 |
# |    clip_fraction        | 0.0807       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.389       |
# |    explained_variance   | 0.325        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0264      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 0.000734     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 495         |
# |    ep_rew_mean          | 495         |
# | time/                   |             |
# |    fps                  | 3369        |
# |    iterations           | 34          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.007947908 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.406      |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.000931   |
# |    value_loss           | 0.000542    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 498         |
# |    ep_rew_mean          | 498         |
# | time/                   |             |
# |    fps                  | 3370        |
# |    iterations           | 35          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004625994 |
# |    clip_fraction        | 0.0404      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.394      |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00924     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 0.000387    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 3371        |
# |    iterations           | 36          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.003519689 |
# |    clip_fraction        | 0.0308      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.372      |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000696    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00256    |
# |    value_loss           | 0.000252    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 3366         |
# |    iterations           | 37           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0042073503 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.366       |
# |    explained_variance   | 0.0707       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0141       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 0.00017      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 3366        |
# |    iterations           | 38          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.002429599 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.361      |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00993    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.000334   |
# |    value_loss           | 0.000114    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 3367        |
# |    iterations           | 39          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004908813 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.37       |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0161     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00227    |
# |    value_loss           | 9.13e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 3368         |
# |    iterations           | 40           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0027410684 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.383       |
# |    explained_variance   | 0.408        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00256      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000373    |
# |    value_loss           | 7.04e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 3370        |
# |    iterations           | 41          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.002945141 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.374      |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0179      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.000822   |
# |    value_loss           | 4.5e-05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 3371         |
# |    iterations           | 42           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0062248455 |
# |    clip_fraction        | 0.0706       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.362       |
# |    explained_variance   | 0.566        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00713     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00532     |
# |    value_loss           | 4.36e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 3371         |
# |    iterations           | 43           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0036779218 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.358       |
# |    explained_variance   | 0.369        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.015       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00432     |
# |    value_loss           | 2.7e-05      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 3373        |
# |    iterations           | 44          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.003112068 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.348      |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00178    |
# |    value_loss           | 1.95e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 3374         |
# |    iterations           | 45           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0027959798 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.324       |
# |    explained_variance   | 0.189        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00525     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00371     |
# |    value_loss           | 1.51e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 3375        |
# |    iterations           | 46          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.003846399 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.337      |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0099     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00264    |
# |    value_loss           | 1.26e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 3373         |
# |    iterations           | 47           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0028417406 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.337       |
# |    explained_variance   | 0.503        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0122       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 6.78e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 3374        |
# |    iterations           | 48          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.001996475 |
# |    clip_fraction        | 0.0231      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.33       |
# |    explained_variance   | -0.142      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.002      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 7.55e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 3365         |
# |    iterations           | 49           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0014363128 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.308       |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00647     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 5.36e-06     |
# ------------------------------------------

# %%
from stable_baselines3.common.vec_env import DummyVecEnv


def make_render_env():
    return gym.make("CartPole-v1", render_mode="human")

env = DummyVecEnv([make_render_env])

# Testowanie modelu
episodes = 5

for episode in range(episodes):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        env.render() 
        action, _states = model.predict(obs)
        obs, reward, done, info = env.step(action)
        total_reward += reward
    print(f"Episode {episode + 1} finished with reward: {total_reward}")

env.close()
# Out:
# Episode 1 finished with reward: [500.]
# Episode 2 finished with reward: [500.]
# Episode 3 finished with reward: [500.]
# Episode 4 finished with reward: [500.]
# Episode 5 finished with reward: [500.]

# %%
class QLearningAgent:

    def __init__(
            self,
            env: gym.Env,
            learning_rate: float,
            initial_epsilon: float,
            epsilon_decay: float,
            final_epsilon: float,
            discount_factor: float = 0.9
    ):

        self.env = env
        self.q_values = defaultdict(lambda: np.zeros(env.action_space.n))

        self.lr = learning_rate
        self.discount_factor = discount_factor

        self.epsilon = initial_epsilon
        self.epsilon_decay = epsilon_decay
        self.final_epsilon = final_epsilon

        self.training_error = []

    def get_action(self, obs: tuple[int, int, bool]) -> int:

        if np.random.random() < self.epsilon:
            return self.env.action_space.sample()
        else:
            return int(np.argmax(self.q_values[obs]))

    def update(
            self,
            obs: tuple[int, int, bool],
            action: int,
            reward: float,
            terminated: bool,
            next_obs: tuple[int, int, bool],
    ):
        future_q_value = (not terminated) * np.max(self.q_values[next_obs])
        temporal_difference = (
                reward + self.discount_factor * future_q_value - self.q_values[obs][action]
        )

        self.q_values[obs][action] = (
                self.q_values[obs][action] + self.lr * temporal_difference
        )
        self.training_error.append(temporal_difference)

    def decay_epsilon(self):
        self.epsilon = max(self.final_epsilon, self.epsilon - self.epsilon_decay)
        
    def get_action_test(self, obs: tuple[int, int, bool]) -> int:
        return int(np.argmax(self.q_values[obs]))

# %%
from tqdm import tqdm


def learn(
        learning_rate: float,
        n_episodes: int,
        start_epsilon: float,
        epsilon_decay: float, 
        final_epsilon: float
        ):
    
    env = gym.make("CliffWalking-v0")
    
    agent = QLearningAgent(
        env=env,
        learning_rate=learning_rate,
        initial_epsilon=start_epsilon,
        epsilon_decay=epsilon_decay,
        final_epsilon=final_epsilon,
    )
    
    for episode in tqdm(range(n_episodes)):
        obs, info = env.reset()
        done = False
    
        while not done:
            action = agent.get_action(obs)
            next_obs, reward, terminated, truncated, info = env.step(action)
    
            agent.update(obs, action, reward, terminated, next_obs)
    
            done = terminated or truncated
            obs = next_obs

        agent.decay_epsilon()
    
    return agent

# %%
learning_rate = 0.01
n_episodes = 50_000
start_epsilon = 1.0
epsilon_decay = start_epsilon / (n_episodes / 2)
final_epsilon = 0.1

# %%
agentQLearning = learn(learning_rate, n_episodes, start_epsilon, epsilon_decay, final_epsilon)
# Out:
# 100%|██████████| 50000/50000 [01:23<00:00, 595.53it/s]

# %%
episodes = 5
env = gym.make("CartPole-v1", render_mode="human")

for episode in range(episodes):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        
        action = agentQLearning.get_action_test(obs)
        next_obs, reward, terminated, truncated, info = env.step(action)
        
        done = terminated or truncated
        obs = next_obs
        total_reward += reward
        
    print(f"Episode {episode + 1} finished with reward: {total_reward}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       7 total_reward = 0
#       8 while not done:
# ---> 10     action = agentQLearning.get_action_test(obs)
#      11     next_obs, reward, terminated, truncated, info = env.step(action)
#      13     done = terminated or truncated
#
# Cell In[2], line 54, in QLearningAgent.get_action_test(self, obs)
#      53 def get_action_test(self, obs: tuple[int, int, bool]) -> int:
# ---> 54     return int(np.argmax(self.q_values[obs]))
#
# TypeError: unhashable type: 'numpy.ndarray'
